# %%
import pandas as pd
import numpy as np
from pathlib import Path
import os

# %%
# Get the current working directory (where your notebook is running)
NOTEBOOK_DIR = Path(os.getcwd())

# Navigate to your dataset subfolder
DATA_DIR = NOTEBOOK_DIR.parent /"raw" / "Disease_and_Mobidity_data"

FILE_NAME = "maternal_and_reproductive_health_indicators_nga.csv"
FILE_PATH = DATA_DIR / FILE_NAME

#print("Looking for file at:", FILE_PATH)

print(DATA_DIR.exists())   # Should be True

# Load dataset
df = pd.read_csv(FILE_PATH)

# === 1. Check basic info ===
print("✅ Dataset loaded successfully!")
print(f"Number of rows: {df.shape[0]}")
print(f"Number of columns: {df.shape[1]}")
print("\n📋 Column names:")
print(df.columns.tolist())
# Out:
# True
# ✅ Dataset loaded successfully!
# Number of rows: 214
# Number of columns: 17
#
# 📋 Column names:
# ['GHO (CODE)', 'GHO (DISPLAY)', 'GHO (URL)', 'YEAR (DISPLAY)', 'STARTYEAR', 'ENDYEAR', 'REGION (CODE)', 'REGION (DISPLAY)', 'COUNTRY (CODE)', 'COUNTRY (DISPLAY)', 'DIMENSION (TYPE)', 'DIMENSION (CODE)', 'DIMENSION (NAME)', 'Numeric', 'Value', 'Low', 'High']

# %%
display(df.head())
# Out:
#                                GHO (CODE)  \
# 0                         #indicator+code
# 1   NUTRITION_ANAEMIA_REPRODUCTIVEAGE_NUM
# 2  NUTRITION_ANAEMIA_REPRODUCTIVEAGE_PREV
# 3  NUTRITION_ANAEMIA_REPRODUCTIVEAGE_PREV
# 4                          MDG_0000000003
#
#                                        GHO (DISPLAY)  \
# 0                                    #indicator+name
# 1  Number of women of reproductive age (aged 15-4...
# 2  Prevalence of anaemia in women of reproductive...
# 3  Prevalence of anaemia in women of reproductive...
# 4             Adolescent birth rate (per 1000 women)
#
#                                            GHO (URL) YEAR (DISPLAY)  \
# 0                                     #indicator+url     #date+year
# 1  https://www.who.int/data/gho/data/indicators/i...           2004
# 2  https://www.who.int/data/gho/data/indicators/i...           2017
# 3  https://www.who.int/data/gho/data/indicators/i...           2015
# 4  https://www.who.int/data/gho/data/indicators/i...           2003
#
#           STARTYEAR         ENDYEAR REGION (CODE) REGION (DISPLAY)  \
# 0  #date+year+start  #date+year+end  #region+code     #region+name
# 1              2004            2004           AFR           Africa
# 2              2017            2017           AFR           Africa
# 3              2015            2015           AFR           Africa
# 4              2003            2003           AFR           Africa
#
#   COUNTRY (CODE) COUNTRY (DISPLAY) DIMENSION (TYPE) DIMENSION (CODE)  \
# 0  #country+code     #country+name  #dimension+type  #dimension+code
# 1            NGA           Nigeria              SEX         SEX_FMLE
# 2            NGA           Nigeria              SEX         SEX_FMLE
# 3            NGA           Nigeria              SEX         SEX_FMLE
# 4            NGA           Nigeria              SEX         SEX_FMLE
#
#   DIMENSION (NAME)               Numeric                   Value  \
# 0  #dimension+name  #indicator+value+num        #indicator+value
# 1           Female                2086.2  2086.2 [1565.9-2579.7]
# 2           Female                  40.7        40.7 [30.7-51.0]
# 3           Female                  41.8        41.8 [30.9-53.4]
# 4           Female                 152.0                   152.0
#
#                     Low                   High
# 0  #indicator+value+low  #indicator+value+high
# 1                1565.9                 2579.7
# 2                  30.7                   51.0
# 3                  30.9                   53.4
# 4                   NaN                    NaN

# %%
# --- Drop the first row ---
df = df.drop(index=0).reset_index(drop=True)

# %%
# Rename columns (matching lowercase names)
# 🧹 Rename columns to clear, Python-friendly names
df.columns = [
    "indicator_code", "indicator_name", "indicator_url", "year",
    "start_year", "end_year", "region_code", "region_name",
    "country_code", "country_name", "sex_type", "sex_code",
    "sex_name", "numeric", "value", "lower_bound", "upper_bound"
]

# ✅ Verify the rename
print("✅ Columns renamed successfully:")
print(df.columns.tolist())

# Optional — quick look at first few rows
display(df.head())
# Out:
# ✅ Columns renamed successfully:
# ['indicator_code', 'indicator_name', 'indicator_url', 'year', 'start_year', 'end_year', 'region_code', 'region_name', 'country_code', 'country_name', 'sex_type', 'sex_code', 'sex_name', 'numeric', 'value', 'lower_bound', 'upper_bound']
#                            indicator_code  \
# 0   NUTRITION_ANAEMIA_REPRODUCTIVEAGE_NUM
# 1  NUTRITION_ANAEMIA_REPRODUCTIVEAGE_PREV
# 2  NUTRITION_ANAEMIA_REPRODUCTIVEAGE_PREV
# 3                          MDG_0000000003
# 4  NUTRITION_ANAEMIA_REPRODUCTIVEAGE_PREV
#
#                                       indicator_name  \
# 0  Number of women of reproductive age (aged 15-4...
# 1  Prevalence of anaemia in women of reproductive...
# 2  Prevalence of anaemia in women of reproductive...
# 3             Adolescent birth rate (per 1000 women)
# 4  Prevalence of anaemia in women of reproductive...
#
#                                        indicator_url  year start_year  \
# 0  https://www.who.int/data/gho/data/indicators/i...  2004       2004
# 1  https://www.who.int/data/gho/data/indicators/i...  2017       2017
# 2  https://www.who.int/data/gho/data/indicators/i...  2015       2015
# 3  https://www.who.int/data/gho/data/indicators/i...  2003       2003
# 4  https://www.who.int/data/gho/data/indicators/i...  2004       2004
#
#   end_year region_code region_name country_code country_name sex_type  \
# 0     2004         AFR      Africa          NGA      Nigeria      SEX
# 1     2017         AFR      Africa          NGA      Nigeria      SEX
# 2     2015         AFR      Africa          NGA      Nigeria      SEX
# 3     2003         AFR      Africa          NGA      Nigeria      SEX
# 4     2004         AFR      Africa          NGA      Nigeria      SEX
#
#    sex_code sex_name numeric                   value lower_bound upper_bound
# 0  SEX_FMLE   Female  2086.2  2086.2 [1565.9-2579.7]      1565.9      2579.7
# 1  SEX_FMLE   Female    40.7        40.7 [30.7-51.0]        30.7        51.0
# 2  SEX_FMLE   Female    41.8        41.8 [30.9-53.4]        30.9        53.4
# 3  SEX_FMLE   Female   152.0                   152.0         NaN         NaN
# 4  SEX_FMLE   Female    53.8        53.8 [40.4-66.5]        40.4        66.5

# %%
# ---Check distinct countries by code and name ---
unique_countries = df[['country_code', 'country_name']].drop_duplicates()
print(f"Distinct countries found: {len(unique_countries)}")
print(unique_countries.head())
# Out:
# Distinct countries found: 1
#   country_code country_name
# 0          NGA      Nigeria

# %%
# ---Check for missing values in all columns ---
missing_values = df.isnull().sum()
print("\nMissing values per column:")
print(missing_values[missing_values > 0])
# Out:
# Missing values per column:
# sex_type       31
# sex_code       31
# sex_name       31
# lower_bound    69
# upper_bound    69
# dtype: int64

# %%
# ---Drop unwanted columns ---
columns_to_drop = ['indicator_url', 'region_code', 'region_name', 'country_code', 'country_name']
df_cleaned = df.drop(columns=columns_to_drop, errors='ignore')

print("\nColumns after dropping:")
print(df_cleaned.columns)
# Out:
# Columns after dropping:
# Index(['indicator_code', 'indicator_name', 'year', 'start_year', 'end_year',
#        'sex_type', 'sex_code', 'sex_name', 'numeric', 'value', 'lower_bound',
#        'upper_bound'],
#       dtype='object')

# %%
# Filter rows where any of the three columns are NOT null
dim_subset = df_cleaned[
    df_cleaned[['sex_code', 'sex_name', 'sex_type']].notnull().any(axis=1)
]

print(f"✅ Rows with dimension-related data: {len(dim_subset)}")
display(dim_subset[['sex_code', 'sex_name', 'sex_type']].head(10))
# Out:
# ✅ Rows with dimension-related data: 182
#     sex_code sex_name sex_type
# 0   SEX_FMLE   Female      SEX
# 1   SEX_FMLE   Female      SEX
# 2   SEX_FMLE   Female      SEX
# 3   SEX_FMLE   Female      SEX
# 4   SEX_FMLE   Female      SEX
# 6   SEX_FMLE   Female      SEX
# 7   SEX_FMLE   Female      SEX
# 8   SEX_FMLE   Female      SEX
# 9   SEX_FMLE   Female      SEX
# 10  SEX_FMLE   Female      SEX

# %%
# Convert to numeric (handles strings safely)
df['numeric'] = pd.to_numeric(df['numeric'], errors='coerce')
df['value'] = pd.to_numeric(df['value'], errors='coerce')
df['lower_bound'] = pd.to_numeric(df['lower_bound'], errors='coerce')
df['upper_bound'] = pd.to_numeric(df['upper_bound'], errors='coerce')

# %%
df_cleaned['lower_bound'].fillna(df['lower_bound'].mean(), inplace=True)
df_cleaned['upper_bound'].fillna(df['upper_bound'].mean(), inplace=True)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_4300\880169563.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_cleaned['lower_bound'].fillna(df['lower_bound'].mean(), inplace=True)
# C:\Users\USER\AppData\Local\Temp\ipykernel_4300\880169563.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_cleaned['upper_bound'].fillna(df['upper_bound'].mean(), inplace=True)

# %%
display(df_cleaned.head())
# Out:
#                            indicator_code  \
# 0   NUTRITION_ANAEMIA_REPRODUCTIVEAGE_NUM
# 1  NUTRITION_ANAEMIA_REPRODUCTIVEAGE_PREV
# 2  NUTRITION_ANAEMIA_REPRODUCTIVEAGE_PREV
# 3                          MDG_0000000003
# 4  NUTRITION_ANAEMIA_REPRODUCTIVEAGE_PREV
#
#                                       indicator_name  year start_year  \
# 0  Number of women of reproductive age (aged 15-4...  2004       2004
# 1  Prevalence of anaemia in women of reproductive...  2017       2017
# 2  Prevalence of anaemia in women of reproductive...  2015       2015
# 3             Adolescent birth rate (per 1000 women)  2003       2003
# 4  Prevalence of anaemia in women of reproductive...  2004       2004
#
#   end_year sex_type  sex_code sex_name numeric                   value  \
# 0     2004      SEX  SEX_FMLE   Female  2086.2  2086.2 [1565.9-2579.7]
# 1     2017      SEX  SEX_FMLE   Female    40.7        40.7 [30.7-51.0]
# 2     2015      SEX  SEX_FMLE   Female    41.8        41.8 [30.9-53.4]
# 3     2003      SEX  SEX_FMLE   Female   152.0                   152.0
# 4     2004      SEX  SEX_FMLE   Female    53.8        53.8 [40.4-66.5]
#
#    lower_bound  upper_bound
# 0       1565.9       2579.7
# 1         30.7         51.0
# 2         30.9         53.4
# 3  4176.167361  7583.347917
# 4         40.4         66.5

# %%
# Replace long-form values with shorter codes
df_cleaned['sex_code'] = df_cleaned['sex_code'].replace({
    'SEX_BTSX': 'BTSX',
    'SEX_MLE': 'MLE',
    'SEX_FMLE': 'FMLE'
})

# Confirm it worked
print(df_cleaned['sex_code'].unique())
# Out:
# ['FMLE' nan]

# %%
# define mapping
sex_mapping = {
    'BTSX': 'Both sexes',
    'MLE': 'Male',
    'FMLE': 'Female'
}
codes = list(sex_mapping.keys())

# check if all values are NaN
if df_cleaned['sex_code'].isna().all():
    # Case 2: All missing — fill everything with BTSX
    df_cleaned['sex_code'] = 'FMLE'
    df_cleaned['sex_name'] = 'Female'
    df_cleaned['sex_type'] = 'Sex'
    print("⚙️ All values missing — filled with SEX_BTSX (Both sexes).")

else:
    # Case 1: Some missing — fill randomly
    np.random.seed(42)  # reproducible random assignment
    mask_missing = df_cleaned['sex_code'].isna()
    df_cleaned.loc[mask_missing, 'sex_code'] = np.random.choice(codes, size=mask_missing.sum())
    
    # Map names and type
    df_cleaned['sex_name'] = df_cleaned['sex_code'].map(sex_mapping)
    df_cleaned['sex_type'] = 'Sex'
    print("✅ Randomly filled missing values with consistent sex codes and names.")

# Verify
display(df_cleaned[['sex_code', 'sex_type', 'sex_name']].drop_duplicates())
# Out:
# ✅ Randomly filled missing values with consistent sex codes and names.
#    sex_code sex_type    sex_name
# 0      FMLE      Sex      Female
# 22     BTSX      Sex  Both sexes
# 44      MLE      Sex        Male

# %%
display(df_cleaned.head())
# Out:
#                            indicator_code  \
# 0   NUTRITION_ANAEMIA_REPRODUCTIVEAGE_NUM
# 1  NUTRITION_ANAEMIA_REPRODUCTIVEAGE_PREV
# 2  NUTRITION_ANAEMIA_REPRODUCTIVEAGE_PREV
# 3                          MDG_0000000003
# 4  NUTRITION_ANAEMIA_REPRODUCTIVEAGE_PREV
#
#                                       indicator_name  year start_year  \
# 0  Number of women of reproductive age (aged 15-4...  2004       2004
# 1  Prevalence of anaemia in women of reproductive...  2017       2017
# 2  Prevalence of anaemia in women of reproductive...  2015       2015
# 3             Adolescent birth rate (per 1000 women)  2003       2003
# 4  Prevalence of anaemia in women of reproductive...  2004       2004
#
#   end_year sex_type sex_code sex_name numeric                   value  \
# 0     2004      SEX     FMLE   Female  2086.2  2086.2 [1565.9-2579.7]
# 1     2017      SEX     FMLE   Female    40.7        40.7 [30.7-51.0]
# 2     2015      SEX     FMLE   Female    41.8        41.8 [30.9-53.4]
# 3     2003      SEX     FMLE   Female   152.0                   152.0
# 4     2004      SEX     FMLE   Female    53.8        53.8 [40.4-66.5]
#
#    lower_bound  upper_bound
# 0       1565.9       2579.7
# 1         30.7         51.0
# 2         30.9         53.4
# 3  4176.167361  7583.347917
# 4         40.4         66.5

# %%
mask = df_cleaned[['sex_code', 'sex_type', 'sex_name']].isna().all(axis=1)
df_cleaned.loc[mask, ['sex_code', 'sex_type', 'sex_name']] = ['FMLE', 'Sex', 'Female']

# %%
# Replace long-form values with shorter codes
df_cleaned['sex_code'] = df_cleaned['sex_code'].replace({
    'SEX_BTSX': 'BTSX',
    'SEX_MLE': 'MLE',
    'SEX_FMLE': 'FMLE'
})

# Confirm it worked
print(df_cleaned['sex_code'].unique())
# Out:
# ['FMLE']

# %%
# Define output file path
output_path = NOTEBOOK_DIR.parent / "processed" / "maternal_and_reproductive_health_indicators_nga.csv"

# Save to CSV
df_cleaned.to_csv(output_path, index=False)

print(f"Filtered data saved to: {output_path}")
print(f"Number of rows left: {len(df_cleaned)}")
# Out:
# Filtered data saved to: C:\Users\USER\Desktop\WORK\RenewedCare\data\processed\maternal_and_reproductive_health_indicators_nga.csv
# Number of rows left: 213
